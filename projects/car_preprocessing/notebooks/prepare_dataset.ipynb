# %% [markdown]
# # Prepare Car Dataset
#
# This notebook demonstrates how to use the `DatasetBuilder` to preprocess the car dataset.
#
# ## Steps:
# 1. Initialize `DatasetBuilder` with raw data path and output path.
# 2. Run the builder to process images.

# %%
import sys
import os

# Add src to path to import modules
sys.path.append(os.path.abspath("../src"))

from dataset_builder.dataset_builder import DatasetBuilder

# %%
# Define paths
RAW_DATA_DIR = "../data/raw"
OUTPUT_DIR = "../data"

# Initialize Builder
builder = DatasetBuilder(RAW_DATA_DIR, OUTPUT_DIR)

# %%
# Run the pipeline
builder.run()
